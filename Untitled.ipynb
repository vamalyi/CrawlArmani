# %%
import pandas as pd

# %%
df = pd.read_csv('output.csv')

# %%
df
# Out:
#      currency                    sku          color     price  category  \
# 0                3YTM60TJ31Z15861586           Blue    145.00       NaN
# 1              9350827P4363643536435           Blue    220.00       NaN
# 2              9350647P4040002000020          Black    180.00       NaN
# 3                3YPV51PJ05Z25BL25BL           Blue    245.00       NaN
# 4              Y1A111YBT1A8007080070           Blue  2,495.00       NaN
# 5              2854287P8310587305873        Fuchsia     75.00       NaN
# 6              2854317P8340001000010          White     95.00       NaN
# 7              2854307P8331477314773        Fuchsia     95.00       NaN
# 8              6277857P5000013400134           Blue    145.00       NaN
# 9                X4X159XG816A178A178          Black    595.00       NaN
# 10               3YTT96TJ12Z01850185          White     95.00       NaN
# 11               3YTF53TJ32Z11001100          White    145.00       NaN
# ...
